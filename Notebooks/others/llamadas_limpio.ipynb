# %% [markdown]
# ## Cosas que si voy a necesitar

# %% [markdown]
# # Codigos de las ligas por APIs
#
# League 1: 61
# Serie A: 135
# BundesLiga: 78
# La liga: 140
# Premier: 29

# %%
#All the teams by league and season - 
#aquí saco todos los equipos de primera de la premier del 2019

import requests

url = "https://api-football-v1.p.rapidapi.com/v3/teams?league=39&season=2019"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'teams', 'parameters': {'league': '39', 'season': '2019'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 1}, 'response': [{'team': {'id': 33, 'name': 'Manchester United', 'code': 'MUN', 'country': 'England', 'founded': 1878, 'national': False, 'logo': 'https://media-4.api-sports.io/football/teams/33.png'}, 'venue': {'id': 556, 'name': 'Old Trafford', 'address': 'Sir Matt Busby Way', 'city': 'Manchester', 'capacity': 76212, 'surface': 'grass', 'image': 'https://media-4.api-sports.io/football/venues/556.png'}}, {'team': {'id': 34, 'name': 'Newcastle', 'code': 'NEW', 'country': 'England', 'founded': 1892, 'national': False, 'logo': 'https://media-4.api-sports.io/football/teams/34.png'}, 'venue': {'id': 562, 'name': "St. James' Park", 'address': 'St. James&apos; Street', 'city': 'Newcastle upon Tyne', 'capacity': 52758, 'surface': 'grass', 'image': 'https://media-4.api-sports.io/football/venues/562.png'}}, {'team': {'id': 35, 'name': 'Bournemouth', 'code': 'BOU',
# ...

# %% [markdown]
# A partir de aquí, el proceso para sacar los equipos

# %%
res_api = response.json()
res_api
# Out:
# {'get': 'teams',
#  'parameters': {'league': '39', 'season': '2019'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'team': {'id': 33,
#     'name': 'Manchester United',
#     'code': 'MUN',
#     'country': 'England',
#     'founded': 1878,
#     'national': False,
#     'logo': 'https://media-4.api-sports.io/football/teams/33.png'},
#    'venue': {'id': 556,
#     'name': 'Old Trafford',
#     'address': 'Sir Matt Busby Way',
#     'city': 'Manchester',
#     'capacity': 76212,
#     'surface': 'grass',
#     'image': 'https://media-4.api-sports.io/football/venues/556.png'}},
#   {'team': {'id': 34,
#     'name': 'Newcastle',
#     'code': 'NEW',
#     'country': 'England',
#     'founded': 1892,
#     'national': False,
#     'logo': 'https://media-4.api-sports.io/football/teams/34.png'},
#    'venue': {'id': 562,
#     'name': "St. James' Park",
#     'address': 'St. James&apos; Street',
#     'city': 'Newcastle upon Tyne',
# ...

# %%
res_api.keys()
# Out:
# dict_keys(['get', 'parameters', 'errors', 'results', 'paging', 'response'])

# %%
len(res_api['response'])  #para ver los 20 equipos
# Out:
# 20

# %%
res_api['response'][0] #primer elemento
# Out:
# {'team': {'id': 33,
#   'name': 'Manchester United',
#   'code': 'MUN',
#   'country': 'England',
#   'founded': 1878,
#   'national': False,
#   'logo': 'https://media-4.api-sports.io/football/teams/33.png'},
#  'venue': {'id': 556,
#   'name': 'Old Trafford',
#   'address': 'Sir Matt Busby Way',
#   'city': 'Manchester',
#   'capacity': 76212,
#   'surface': 'grass',
#   'image': 'https://media-4.api-sports.io/football/venues/556.png'}}

# %%
res_api['response'][0].keys() #ver las keys del dicionario.
# Out:
# dict_keys(['team', 'venue'])

# %%
res_api['response'][0]['team']['name'] #lo que quiero que me saque del apartado response
# Out:
# 'Manchester United'

# %%
#La funcion para sacar el nombre de los 20 equipos que jugaron el el 19 en la premier.
#Si repito el patrón con las ligas que quiero. pues listo. 

for e in res_api['response']:
    print (e['team']['name'])
# Out:
# Manchester United
# Newcastle
# Bournemouth
# Watford
# Wolves
# Liverpool
# Southampton
# Arsenal
# Burnley
# Everton
# Leicester
# Tottenham
# West Ham
# Chelsea
# Manchester City
# Brighton
# Crystal Palace
# Sheffield Utd
# Aston Villa
# Norwich

# %% [markdown]
# ## Estadísticas de cada equipo y jugador por temporada.

# %%
#Estadisticas de cada jugador por equipo/temporada. 
#el código del equipo viene de lo que he visto antes. 
#la temporada, elijo yo.


import requests

url = "https://api-football-v1.p.rapidapi.com/v3/players?season=2018&team=33"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'players', 'parameters': {'season': '2018', 'team': '33'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 2}, 'response': [{'player': {'id': 882, 'name': 'David de Gea', 'firstname': 'David', 'lastname': 'de Gea Quintana', 'age': 33, 'birth': {'date': '1990-11-07', 'place': 'Madrid', 'country': 'Spain'}, 'nationality': 'Spain', 'height': '192 cm', 'weight': '76 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/882.png'}, 'statistics': [{'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media-4.api-sports.io/football/teams/33.png'}, 'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media-4.api-sports.io/football/leagues/39.png', 'flag': 'https://media-4.api-sports.io/flags/gb.svg', 'season': 2018}, 'games': {'appearences': 38, 'lineups': 38, 'minutes': 3420, 'number': None, 'position': 'Goalkeeper', 'rating': '6.647368', 'captain': False}, 'substitutes': {'in': 0, 'out': 0, 'bench'
# ...

# %%
res_api_2 = response.json()
res_api_2
# Out:
# {'get': 'players',
#  'parameters': {'season': '2018', 'team': '33'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 2},
#  'response': [{'player': {'id': 882,
#     'name': 'David de Gea',
#     'firstname': 'David',
#     'lastname': 'de Gea Quintana',
#     'age': 33,
#     'birth': {'date': '1990-11-07', 'place': 'Madrid', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '192 cm',
#     'weight': '76 kg',
#     'injured': False,
#     'photo': 'https://media-4.api-sports.io/football/players/882.png'},
#    'statistics': [{'team': {'id': 33,
#       'name': 'Manchester United',
#       'logo': 'https://media-4.api-sports.io/football/teams/33.png'},
#      'league': {'id': 39,
#       'name': 'Premier League',
#       'country': 'England',
#       'logo': 'https://media-4.api-sports.io/football/leagues/39.png',
#       'flag': 'https://media-4.api-sports.io/flags/gb.svg',
#       'season': 2018},
#      'games': {'appearences': 38,
# ...

# %% [markdown]
# ## Estadisticas de cada jugador por equipo/temporada.

# %%
#Estadisticas de cada jugador por equipo/temporada. 
#veces que jugo/minutos que jugo/si hubo lesión o no. Posición.
#el código del equipo viene de lo que he visto antes. 
#la temporada, elijo yo.


import requests

url = "https://api-football-v1.p.rapidapi.com/v3/players?season=2018&team=42"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'players', 'parameters': {'season': '2018', 'team': '42'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 3}, 'response': [{'player': {'id': 1436, 'name': 'Petr Čech', 'firstname': 'Petr', 'lastname': 'Čech', 'age': 40, 'birth': {'date': '1982-05-20', 'place': 'Plzeň', 'country': 'Czech Republic'}, 'nationality': 'Czech Republic', 'height': '196 cm', 'weight': '90 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/1436.png'}, 'statistics': [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media-4.api-sports.io/football/teams/42.png'}, 'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media-4.api-sports.io/football/leagues/39.png', 'flag': 'https://media-4.api-sports.io/flags/gb.svg', 'season': 2018}, 'games': {'appearences': 7, 'lineups': 7, 'minutes': 585, 'number': None, 'position': 'Goalkeeper', 'rating': '7.085714', 'captain': False}, 'substitutes': {'in': 0, 'out': 1, 'bench': 29}, 's
# ...

# %%
res_api_3 = response.json()
res_api_3
# Out:
# {'get': 'players',
#  'parameters': {'season': '2018', 'team': '42'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 3},
#  'response': [{'player': {'id': 1436,
#     'name': 'Petr Čech',
#     'firstname': 'Petr',
#     'lastname': 'Čech',
#     'age': 40,
#     'birth': {'date': '1982-05-20',
#      'place': 'Plzeň',
#      'country': 'Czech Republic'},
#     'nationality': 'Czech Republic',
#     'height': '196 cm',
#     'weight': '90 kg',
#     'injured': False,
#     'photo': 'https://media-4.api-sports.io/football/players/1436.png'},
#    'statistics': [{'team': {'id': 42,
#       'name': 'Arsenal',
#       'logo': 'https://media-4.api-sports.io/football/teams/42.png'},
#      'league': {'id': 39,
#       'name': 'Premier League',
#       'country': 'England',
#       'logo': 'https://media-4.api-sports.io/football/leagues/39.png',
#       'flag': 'https://media-4.api-sports.io/flags/gb.svg',
#       'season': 2018},
#      'games': {'appearences': 7,
# ...

# %% [markdown]
# ## Jugadores por equipo/temporada

# %%
#Jugadores por temporada/equipo. 
# #team 42 es arsenal

import requests

url = "https://api-football-v1.p.rapidapi.com/v3/players?season=2018&team=42"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'players', 'parameters': {'season': '2018', 'team': '42'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 3}, 'response': [{'player': {'id': 1436, 'name': 'Petr Čech', 'firstname': 'Petr', 'lastname': 'Čech', 'age': 40, 'birth': {'date': '1982-05-20', 'place': 'Plzeň', 'country': 'Czech Republic'}, 'nationality': 'Czech Republic', 'height': '196 cm', 'weight': '90 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/1436.png'}, 'statistics': [{'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media-4.api-sports.io/football/teams/42.png'}, 'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media-4.api-sports.io/football/leagues/39.png', 'flag': 'https://media-4.api-sports.io/flags/gb.svg', 'season': 2018}, 'games': {'appearences': 7, 'lineups': 7, 'minutes': 585, 'number': None, 'position': 'Goalkeeper', 'rating': '7.085714', 'captain': False}, 'substitutes': {'in': 0, 'out': 1, 'bench': 29}, 's
# ...

# %%
res_api_4= response.json()
res_api_4
# Out:
# {'get': 'players',
#  'parameters': {'season': '2018', 'team': '42'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 3},
#  'response': [{'player': {'id': 1436,
#     'name': 'Petr Čech',
#     'firstname': 'Petr',
#     'lastname': 'Čech',
#     'age': 40,
#     'birth': {'date': '1982-05-20',
#      'place': 'Plzeň',
#      'country': 'Czech Republic'},
#     'nationality': 'Czech Republic',
#     'height': '196 cm',
#     'weight': '90 kg',
#     'injured': False,
#     'photo': 'https://media-4.api-sports.io/football/players/1436.png'},
#    'statistics': [{'team': {'id': 42,
#       'name': 'Arsenal',
#       'logo': 'https://media-4.api-sports.io/football/teams/42.png'},
#      'league': {'id': 39,
#       'name': 'Premier League',
#       'country': 'England',
#       'logo': 'https://media-4.api-sports.io/football/leagues/39.png',
#       'flag': 'https://media-4.api-sports.io/flags/gb.svg',
#       'season': 2018},
#      'games': {'appearences': 7,
# ...

# %% [markdown]
# ## Lesiones por temporada/equipo/jugadores lesionados

# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/injuries?team=85&season=2020"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'injuries', 'parameters': {'team': '85', 'season': '2020'}, 'errors': [], 'results': 53, 'paging': {'current': 1, 'total': 1}, 'response': [{'player': {'id': 258, 'name': 'J. Bernat', 'photo': 'https://media-4.api-sports.io/football/players/258.png', 'type': 'Missing Fixture', 'reason': 'Knee Injury'}, 'team': {'id': 85, 'name': 'Paris Saint Germain', 'logo': 'https://media-4.api-sports.io/football/teams/85.png'}, 'fixture': {'id': 686314, 'timezone': 'UTC', 'date': '2021-04-07T19:00:00+00:00', 'timestamp': 1617822000}, 'league': {'id': 2, 'season': 2020, 'name': 'UEFA Champions League', 'country': 'World', 'logo': 'https://media-4.api-sports.io/football/leagues/2.png', 'flag': None}}, {'player': {'id': 769, 'name': 'A. Florenzi', 'photo': 'https://media-4.api-sports.io/football/players/769.png', 'type': 'Missing Fixture', 'reason': 'Illness'}, 'team': {'id': 85, 'name': 'Paris Saint Germain', 'logo': 'https://media-4.api-sports.io/football/teams/85.png'}, 'fixture': {'id': 6
# ...

# %%
res_api_5 = response.json()
res_api_5
# Out:
# {'get': 'injuries',
#  'parameters': {'team': '85', 'season': '2020'},
#  'errors': [],
#  'results': 53,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'player': {'id': 258,
#     'name': 'J. Bernat',
#     'photo': 'https://media-4.api-sports.io/football/players/258.png',
#     'type': 'Missing Fixture',
#     'reason': 'Knee Injury'},
#    'team': {'id': 85,
#     'name': 'Paris Saint Germain',
#     'logo': 'https://media-4.api-sports.io/football/teams/85.png'},
#    'fixture': {'id': 686314,
#     'timezone': 'UTC',
#     'date': '2021-04-07T19:00:00+00:00',
#     'timestamp': 1617822000},
#    'league': {'id': 2,
#     'season': 2020,
#     'name': 'UEFA Champions League',
#     'country': 'World',
#     'logo': 'https://media-4.api-sports.io/football/leagues/2.png',
#     'flag': None}},
#   {'player': {'id': 769,
#     'name': 'A. Florenzi',
#     'photo': 'https://media-4.api-sports.io/football/players/769.png',
#     'type': 'Missing Fixture',
# ...
