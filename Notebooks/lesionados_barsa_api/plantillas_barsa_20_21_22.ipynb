# %% [markdown]
# ## Plantilas Barsa
#
# 2020-21
#
# 2021-22
#
# 2022-23

# %%
import requests

# %%
#Plantilla barsa 2020

url = "https://api-football-v1.p.rapidapi.com/v3/players?season=2020&team=529"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response_2020= requests.get(url, headers=headers)

print(response_2020.json())
# Out:
# {'get': 'players', 'parameters': {'season': '2020', 'team': '529'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 3}, 'response': [{'player': {'id': 136, 'name': 'Piqué', 'firstname': 'Gerard', 'lastname': 'Piqué Bernabéu', 'age': 35, 'birth': {'date': '1987-02-02', 'place': 'Barcelona', 'country': 'Spain'}, 'nationality': 'Spain', 'height': '194 cm', 'weight': '85 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/136.png'}, 'statistics': [{'team': {'id': 529, 'name': 'Barcelona', 'logo': 'https://media-4.api-sports.io/football/teams/529.png'}, 'league': {'id': 140, 'name': 'La Liga', 'country': 'Spain', 'logo': 'https://media-4.api-sports.io/football/leagues/140.png', 'flag': 'https://media-4.api-sports.io/flags/es.svg', 'season': 2020}, 'games': {'appearences': 18, 'lineups': 18, 'minutes': 1485, 'number': None, 'position': 'Defender', 'rating': '6.983333', 'captain': False}, 'substitutes': {'in': 0, 'out': 5, 'bench': 2}, 'shots': {'t
# ...

# %%
res_api_2020 = response_2020.json()

res_api_2020
# Out:
# {'get': 'players',
#  'parameters': {'season': '2020', 'team': '529'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 3},
#  'response': [{'player': {'id': 136,
#     'name': 'Piqué',
#     'firstname': 'Gerard',
#     'lastname': 'Piqué Bernabéu',
#     'age': 35,
#     'birth': {'date': '1987-02-02', 'place': 'Barcelona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '194 cm',
#     'weight': '85 kg',
#     'injured': False,
#     'photo': 'https://media-4.api-sports.io/football/players/136.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media-4.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media-4.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media-4.api-sports.io/flags/es.svg',
#       'season': 2020},
#      'games': {'appearences': 18,
#       'lineups': 18,
# ...

# %%
#Plantilla Barsa 2021

url = "https://api-football-v1.p.rapidapi.com/v3/players?season=2021&team=529"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response_2021 = requests.get(url, headers=headers)

print(response_2021.json())
# Out:
# {'get': 'players', 'parameters': {'season': '2021', 'team': '529'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 4}, 'response': [{'player': {'id': 132, 'name': 'Guillem Jaime', 'firstname': 'Guillem', 'lastname': 'Jaime Serrano', 'age': 24, 'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'}, 'nationality': 'Spain', 'height': '177 cm', 'weight': '70 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/132.png'}, 'statistics': [{'team': {'id': 529, 'name': 'Barcelona', 'logo': 'https://media-4.api-sports.io/football/teams/529.png'}, 'league': {'id': 140, 'name': 'La Liga', 'country': 'Spain', 'logo': 'https://media-4.api-sports.io/football/leagues/140.png', 'flag': 'https://media-4.api-sports.io/flags/es.svg', 'season': 2021}, 'games': {'appearences': 0, 'lineups': 0, 'minutes': 0, 'number': None, 'position': 'Defender', 'rating': None, 'captain': False}, 'substitutes': {'in': 0, 'out': 0, 'bench': 2}, 'shots': {'tota
# ...

# %%
res_api_2021 = response_2021.json()

res_api_2021
# Out:
# {'get': 'players',
#  'parameters': {'season': '2021', 'team': '529'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 4},
#  'response': [{'player': {'id': 132,
#     'name': 'Guillem Jaime',
#     'firstname': 'Guillem',
#     'lastname': 'Jaime Serrano',
#     'age': 24,
#     'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '177 cm',
#     'weight': '70 kg',
#     'injured': False,
#     'photo': 'https://media-4.api-sports.io/football/players/132.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media-4.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media-4.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media-4.api-sports.io/flags/es.svg',
#       'season': 2021},
#      'games': {'appearences': 0,
# ...

# %%
#Plantilla Barsa 2022

url = "https://api-football-v1.p.rapidapi.com/v3/players?season=2022&team=529"

headers = {
	"X-RapidAPI-Key": "5c362a3846msha4ff5449315b3b5p1e1d33jsn8f369b5ae44a",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response_2022 = requests.get(url, headers=headers)

print(response_2022.json())
# Out:
# {'get': 'players', 'parameters': {'season': '2022', 'team': '529'}, 'errors': [], 'results': 20, 'paging': {'current': 1, 'total': 4}, 'response': [{'player': {'id': 132, 'name': 'Guillem Jaime', 'firstname': 'Guillem', 'lastname': 'Jaime Serrano', 'age': 24, 'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'}, 'nationality': 'Spain', 'height': '177 cm', 'weight': '70 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/132.png'}, 'statistics': [{'team': {'id': 529, 'name': 'Barcelona', 'logo': 'https://media-4.api-sports.io/football/teams/529.png'}, 'league': {'id': 667, 'name': 'Friendlies Clubs', 'country': 'World', 'logo': 'https://media-4.api-sports.io/football/leagues/667.png', 'flag': None, 'season': 2022}, 'games': {'appearences': 0, 'lineups': 0, 'minutes': 0, 'number': None, 'position': 'Defender', 'rating': None, 'captain': False}, 'substitutes': {'in': 0, 'out': 0, 'bench': 0}, 'shots': {'total': None, 'on': None}, 'goals':
# ...

# %%
res_api_2022 = response_2022.json()

res_api_2022
# Out:
# {'get': 'players',
#  'parameters': {'season': '2022', 'team': '529'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 4},
#  'response': [{'player': {'id': 132,
#     'name': 'Guillem Jaime',
#     'firstname': 'Guillem',
#     'lastname': 'Jaime Serrano',
#     'age': 24,
#     'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '177 cm',
#     'weight': '70 kg',
#     'injured': False,
#     'photo': 'https://media-4.api-sports.io/football/players/132.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media-4.api-sports.io/football/teams/529.png'},
#      'league': {'id': 667,
#       'name': 'Friendlies Clubs',
#       'country': 'World',
#       'logo': 'https://media-4.api-sports.io/football/leagues/667.png',
#       'flag': None,
#       'season': 2022},
#      'games': {'appearences': 0,
#       'lineups': 0,
#       'minutes': 0,
# ...

# %% [markdown]
# ## Para MongoDB

# %%
from pymongo import MongoClient
cursor = MongoClient()   # no esta escrita la string de conexion

cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
str_conn = 'mongodb://localhost:27017'   # str_con por defecto

cursor = MongoClient(str_conn)

cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = cursor.plantillas_barsa_2010

prueba_1 = db.plantillas_barsa_2020

# %%
prueba_1.insert_one(res_api_2022)

# %% [markdown]
# ## Crear DF de las plantillas de los años:
#
# 2020-21
#
# 2021-22
#
# 2022-23

# %%
import pymongo
import pandas as pd
from bson import ObjectId

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")
db = client['plantillas_barsa_2010']
collection = db['plantillas_barsa_2020']

# %% [markdown]
# ## Plantilla 2020

# %%
#plantilla 2020

target_id = ObjectId("656dff033c0e2f70746c250a") #Cambiando el Id de cada uno, tendré la plantilla correspondiente. 
query = {"_id": target_id}
data_from_mongo20 = collection.find_one(query)

# %%
data_from_mongo20
# Out:
# {'_id': ObjectId('656dff033c0e2f70746c250a'),
#  'get': 'players',
#  'parameters': {'season': '2020', 'team': '529'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 3},
#  'response': [{'player': {'id': 136,
#     'name': 'Piqué',
#     'firstname': 'Gerard',
#     'lastname': 'Piqué Bernabéu',
#     'age': 35,
#     'birth': {'date': '1987-02-02', 'place': 'Barcelona', 'country': 'Spain'},
#     'nationality': 'Spain',
#     'height': '194 cm',
#     'weight': '85 kg',
#     'injured': False,
#     'photo': 'https://media-4.api-sports.io/football/players/136.png'},
#    'statistics': [{'team': {'id': 529,
#       'name': 'Barcelona',
#       'logo': 'https://media-4.api-sports.io/football/teams/529.png'},
#      'league': {'id': 140,
#       'name': 'La Liga',
#       'country': 'Spain',
#       'logo': 'https://media-4.api-sports.io/football/leagues/140.png',
#       'flag': 'https://media-4.api-sports.io/flags/es.svg',
#       'season': 2020},
# ...

# %%
data_from_mongo2020 = [data_from_mongo20] if data_from_mongo20 else []

data_from_mongo2020
# Out:
# [{'_id': ObjectId('656dff033c0e2f70746c250a'),
#   'get': 'players',
#   'parameters': {'season': '2020', 'team': '529'},
#   'errors': [],
#   'results': 20,
#   'paging': {'current': 1, 'total': 3},
#   'response': [{'player': {'id': 136,
#      'name': 'Piqué',
#      'firstname': 'Gerard',
#      'lastname': 'Piqué Bernabéu',
#      'age': 35,
#      'birth': {'date': '1987-02-02', 'place': 'Barcelona', 'country': 'Spain'},
#      'nationality': 'Spain',
#      'height': '194 cm',
#      'weight': '85 kg',
#      'injured': False,
#      'photo': 'https://media-4.api-sports.io/football/players/136.png'},
#     'statistics': [{'team': {'id': 529,
#        'name': 'Barcelona',
#        'logo': 'https://media-4.api-sports.io/football/teams/529.png'},
#       'league': {'id': 140,
#        'name': 'La Liga',
#        'country': 'Spain',
#        'logo': 'https://media-4.api-sports.io/football/leagues/140.png',
#        'flag': 'https://media-4.api-sports.io/flags/es.svg',
# ...

# %%
for e in range(len(data_from_mongo2020)):
    for i in range(len(data_from_mongo2020[e])):
        print(data_from_mongo2020[e]['response'][i]['player'])
        print(data_from_mongo2020[e]['response'][i]['statistics'])
# Out:
# {'id': 136, 'name': 'Piqué', 'firstname': 'Gerard', 'lastname': 'Piqué Bernabéu', 'age': 35, 'birth': {'date': '1987-02-02', 'place': 'Barcelona', 'country': 'Spain'}, 'nationality': 'Spain', 'height': '194 cm', 'weight': '85 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/136.png'}
# ...

# %%
data_list = []

for e in range(len(data_from_mongo2020)):
    for i in range(len(data_from_mongo2020[e]['response'])):
        for a in range (len(data_from_mongo2020[e]['response'][i]['statistics'])):
            player_data = data_from_mongo2020[e]['response'][i]['player']
            statistics_data = data_from_mongo2020[e]['response'][i]['statistics'][a]
            other = data_from_mongo2020[e]['response'][i]['statistics'][a]['team']

            # Extract relevant information
            player_info = {
                'id': player_data['id'],
                'name': player_data['name'],
                'firstname': player_data['firstname'],
                'age': player_data['age'],
                'birth_date': player_data['birth']['date'],
                'nationality': player_data['nationality'],
                'height': player_data['height'],
                'weight': player_data['weight'],
                'injured': player_data['injured'],
                'league': statistics_data['league']['name'],
                'team': statistics_data['team']['name'],
                'season': statistics_data['league']['season'],
                'games_appearances': statistics_data['games']['appearences'],
                'games_lineups': statistics_data['games']['lineups'],
                'games_minutes': statistics_data['games']['minutes'],
                'games_position': statistics_data['games']['position'],
                #'champios': statistics_data[0]['team']['league']['name']
            }

            data_list.append(player_info)

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(data_list)

# Display the DataFrame
plantilla_2020 = df

plantilla_2020
# Out:
#         id               name       firstname  age  birth_date  \
# 0      136              Piqué          Gerard   35  1987-02-02
# 1      136              Piqué          Gerard   35  1987-02-02
# 2      136              Piqué          Gerard   35  1987-02-02
# 3      136              Piqué          Gerard   35  1987-02-02
# 4      141           M. Wagué          Moussa   25  1998-10-04
# 5      142            Rafinha          Rafael   31  1992-02-12
# 6      142            Rafinha          Rafael   31  1992-02-12
# 7      142            Rafinha          Rafael   31  1992-02-12
# 8      144    Sergio Busquets          Sergio   35  1988-07-16
# 9      144    Sergio Busquets          Sergio   35  1988-07-16
# 10     144    Sergio Busquets          Sergio   35  1988-07-16
# 11     144    Sergio Busquets          Sergio   35  1988-07-16
# 12     147  Philippe Coutinho        Philippe   31  1992-06-12
# 13     147  Philippe Coutinho        Philippe   31  1992-06-12
# ...

# %% [markdown]
# ## Plantilla 2021

# %%
target_id = ObjectId("656dff053c0e2f70746c250b") #Cambiando el Id de cada uno, tendré la plantilla correspondiente. 
query = {"_id": target_id}
data_from_mongo21 = collection.find_one(query)

# %%
data_from_mongo2021 = [data_from_mongo21] if data_from_mongo21 else []

data_from_mongo2021
# Out:
# [{'_id': ObjectId('656dff053c0e2f70746c250b'),
#   'get': 'players',
#   'parameters': {'season': '2021', 'team': '529'},
#   'errors': [],
#   'results': 20,
#   'paging': {'current': 1, 'total': 4},
#   'response': [{'player': {'id': 132,
#      'name': 'Guillem Jaime',
#      'firstname': 'Guillem',
#      'lastname': 'Jaime Serrano',
#      'age': 24,
#      'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'},
#      'nationality': 'Spain',
#      'height': '177 cm',
#      'weight': '70 kg',
#      'injured': False,
#      'photo': 'https://media-4.api-sports.io/football/players/132.png'},
#     'statistics': [{'team': {'id': 529,
#        'name': 'Barcelona',
#        'logo': 'https://media-4.api-sports.io/football/teams/529.png'},
#       'league': {'id': 140,
#        'name': 'La Liga',
#        'country': 'Spain',
#        'logo': 'https://media-4.api-sports.io/football/leagues/140.png',
#        'flag': 'https://media-4.api-sports.io/flags/es.svg',
# ...

# %%
for e in range(len(data_from_mongo2021)):
    for i in range(len(data_from_mongo2021[e])):
        print(data_from_mongo2021[e]['response'][i]['player'])
        print(data_from_mongo2021[e]['response'][i]['statistics'])
# Out:
# {'id': 132, 'name': 'Guillem Jaime', 'firstname': 'Guillem', 'lastname': 'Jaime Serrano', 'age': 24, 'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'}, 'nationality': 'Spain', 'height': '177 cm', 'weight': '70 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/132.png'}
# ...

# %%
data_list = []

for e in range(len(data_from_mongo2021)):
    for i in range(len(data_from_mongo2021[e]['response'])):
        for a in range (len(data_from_mongo2021[e]['response'][i]['statistics'])):
            player_data = data_from_mongo2021[e]['response'][i]['player']
            statistics_data = data_from_mongo2021[e]['response'][i]['statistics'][a]
            other = data_from_mongo2021[e]['response'][i]['statistics'][a]['team']

            # Extract relevant information
            player_info = {
                'id': player_data['id'],
                'name': player_data['name'],
                'firstname': player_data['firstname'],
                'age': player_data['age'],
                'birth_date': player_data['birth']['date'],
                'nationality': player_data['nationality'],
                'height': player_data['height'],
                'weight': player_data['weight'],
                'injured': player_data['injured'],
                'league': statistics_data['league']['name'],
                'team': statistics_data['team']['name'],
                'season': statistics_data['league']['season'],
                'games_appearances': statistics_data['games']['appearences'],
                'games_lineups': statistics_data['games']['lineups'],
                'games_minutes': statistics_data['games']['minutes'],
                'games_position': statistics_data['games']['position'],
                #'champios': statistics_data[0]['team']['league']['name']
            }

            data_list.append(player_info)

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(data_list)

# Display the DataFrame
plantilla_2021 = df

plantilla_2021
# Out:
#         id           name      firstname  age  birth_date nationality  height  \
# 0      132  Guillem Jaime        Guillem   24  1999-01-06       Spain  177 cm
# 1      132  Guillem Jaime        Guillem   24  1999-01-06       Spain  177 cm
# 2      132  Guillem Jaime        Guillem   24  1999-01-06       Spain  177 cm
# 3      136          Piqué         Gerard   35  1987-02-02       Spain  194 cm
# 4      136          Piqué         Gerard   35  1987-02-02       Spain  194 cm
# ..     ...            ...            ...  ...         ...         ...     ...
# 57  162473    Arnau Tenas          Arnau   22  2001-05-30       Spain  185 cm
# 58  162710     Peque Polo  Carlos Javier   23  2000-10-02       Spain    None
# 59  163466     L. Carević          Lazar   24  1999-03-16  Montenegro  193 cm
# 60  163466     L. Carević          Lazar   24  1999-03-16  Montenegro  193 cm
# 61  163466     L. Carević          Lazar   24  1999-03-16  Montenegro  193 cm
#
# ...

# %% [markdown]
# ## Plantilla 2022

# %%
target_id = ObjectId("656dff083c0e2f70746c250c") #Cambiando el Id de cada uno, tendré la plantilla correspondiente. 
query = {"_id": target_id}
data_from_mongo22 = collection.find_one(query)

# %%
data_from_mongo2022 = [data_from_mongo22] if data_from_mongo22 else []

data_from_mongo2022
# Out:
# [{'_id': ObjectId('656dff083c0e2f70746c250c'),
#   'get': 'players',
#   'parameters': {'season': '2022', 'team': '529'},
#   'errors': [],
#   'results': 20,
#   'paging': {'current': 1, 'total': 4},
#   'response': [{'player': {'id': 132,
#      'name': 'Guillem Jaime',
#      'firstname': 'Guillem',
#      'lastname': 'Jaime Serrano',
#      'age': 24,
#      'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'},
#      'nationality': 'Spain',
#      'height': '177 cm',
#      'weight': '70 kg',
#      'injured': False,
#      'photo': 'https://media-4.api-sports.io/football/players/132.png'},
#     'statistics': [{'team': {'id': 529,
#        'name': 'Barcelona',
#        'logo': 'https://media-4.api-sports.io/football/teams/529.png'},
#       'league': {'id': 667,
#        'name': 'Friendlies Clubs',
#        'country': 'World',
#        'logo': 'https://media-4.api-sports.io/football/leagues/667.png',
#        'flag': None,
#        'season': 2022},
# ...

# %%
for e in range(len(data_from_mongo2022)):
    for i in range(len(data_from_mongo2022[e])):
        print(data_from_mongo2022[e]['response'][i]['player'])
        print(data_from_mongo2022[e]['response'][i]['statistics'])
# Out:
# {'id': 132, 'name': 'Guillem Jaime', 'firstname': 'Guillem', 'lastname': 'Jaime Serrano', 'age': 24, 'birth': {'date': '1999-01-06', 'place': 'Tarragona', 'country': 'Spain'}, 'nationality': 'Spain', 'height': '177 cm', 'weight': '70 kg', 'injured': False, 'photo': 'https://media-4.api-sports.io/football/players/132.png'}
# ...

# %%
data_list = []

for e in range(len(data_from_mongo2022)):
    for i in range(len(data_from_mongo2022[e]['response'])):
        for a in range (len(data_from_mongo2022[e]['response'][i]['statistics'])):
            player_data = data_from_mongo2022[e]['response'][i]['player']
            statistics_data = data_from_mongo2022[e]['response'][i]['statistics'][a]
            other = data_from_mongo2022[e]['response'][i]['statistics'][a]['team']

            # Extract relevant information
            player_info = {
                'id': player_data['id'],
                'name': player_data['name'],
                'firstname': player_data['firstname'],
                'age': player_data['age'],
                'birth_date': player_data['birth']['date'],
                'nationality': player_data['nationality'],
                'height': player_data['height'],
                'weight': player_data['weight'],
                'injured': player_data['injured'],
                'league': statistics_data['league']['name'],
                'team': statistics_data['team']['name'],
                'season': statistics_data['league']['season'],
                'games_appearances': statistics_data['games']['appearences'],
                'games_lineups': statistics_data['games']['lineups'],
                'games_minutes': statistics_data['games']['minutes'],
                'games_position': statistics_data['games']['position'],
                #'champios': statistics_data[0]['team']['league']['name']
            }

            data_list.append(player_info)

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(data_list)

# Display the DataFrame
plantilla_2022 = df

plantilla_2022
# Out:
#         id               name     firstname  age  birth_date  \
# 0      132      Guillem Jaime       Guillem   24  1999-01-06
# 1      136              Piqué        Gerard   35  1987-02-02
# 2      136              Piqué        Gerard   35  1987-02-02
# 3      136              Piqué        Gerard   35  1987-02-02
# 4      147  Philippe Coutinho      Philippe   31  1992-06-12
# 5      153         O. Dembélé          None   26        None
# 6      153         O. Dembélé          None   26        None
# 7      153         O. Dembélé          None   26        None
# 8      153         O. Dembélé          None   26        None
# 9      153         O. Dembélé          None   26        None
# 10     256         Dani Alves        Daniel   40  1983-05-06
# 11     872          M. Pjanić       Miralem   33  1990-04-02
# 12     872          M. Pjanić       Miralem   33  1990-04-02
# 13     872          M. Pjanić       Miralem   33  1990-04-02
# ...

# %%
plantilla_2022_path  = '/Users/edgarahmed/Desktop/ironhack/semana_8/modelo predictivo/plantillas_lesionados_barsa_csv/plantilla_2022.csv'


plantilla_2022.to_csv(plantilla_2022_path, index=False)
